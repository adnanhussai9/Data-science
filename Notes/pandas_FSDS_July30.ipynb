# %%
import pandas as pd

# %%
df=pd.read_csv("C:\Downloads\data fsds\sales_data_final.csv")
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df["order_date"]
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
type(df["order_date"])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df["order_date"]
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
type(df["order_date"])
# Out:
# pandas.core.series.Series

# %%
df[["order_date"]]
# Out:
#        order_date
# 0        1/1/2011
# 1        1/1/2011
# 2        1/1/2011
# 3        1/1/2011
# 4        1/1/2011
# ...           ...
# 51285  12/31/2014
# 51286  12/31/2014
# 51287  12/31/2014
# 51288  12/31/2014
# 51289  12/31/2014
#
# [51290 rows x 1 columns]

# %%
type(df[['order_date']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["order_date","country"]]
# Out:
#        order_date        country
# 0        1/1/2011        Algeria
# 1        1/1/2011      Australia
# 2        1/1/2011        Hungary
# 3        1/1/2011         Sweden
# 4        1/1/2011      Australia
# ...           ...            ...
# 51285  12/31/2014  United States
# 51286  12/31/2014        Morocco
# 51287  12/31/2014      Nicaragua
# 51288  12/31/2014         Mexico
# 51289  12/31/2014  United States
#
# [51290 rows x 2 columns]

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.dtypes[df.dtypes=="object"]
# Out:
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_name     object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# order_priority    object
# dtype: object

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'order_priority'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes=="object"].index]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[df.dtypes[df.dtypes=="object"].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df[df.dtypes[df.dtypes=="float64"].index]
# Out:
#        discount    profit  shipping_cost
# 0           0.0  106.1400          35.46
# 1           0.1   36.0360           9.72
# 2           0.0   29.6400           8.17
# 3           0.5  -26.0550           4.82
# 4           0.1   37.7700           4.70
# ...         ...       ...            ...
# 51285       0.2    4.5188           0.89
# 51286       0.0    0.4200           0.49
# 51287       0.0   12.3600           0.35
# 51288       0.0    0.5600           0.20
# 51289       0.2   -0.6048           0.17
#
# [51290 rows x 3 columns]

# %%
df["order_id"][1:6:2]
# Out:
# 1      IN-2011-47883
# 3    IT-2011-3647632
# 5      IN-2011-47883
# Name: order_id, dtype: object

# %%
df["order_id"].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: order_id, Length: 51290, dtype: bool

# %%
df[df["profit"]==max(df["profit"])]
# Out:
#              order_id order_date   ship_date       ship_mode customer_name  \
# 29530  CA-2013-118689  10/3/2013  10/10/2013  Standard Class  Tamara Chand
#
#          segment    state        country market   region  ...    category  \
# 29530  Corporate  Indiana  United States     US  Central  ...  Technology
#
#       sub_category                           product_name   sales quantity  \
# 29530      Copiers  Canon imageCLASS 2200 Advanced Copier  17,500        5
#
#        discount    profit  shipping_cost  order_priority  year
# 29530       0.0  8399.976         349.07          Medium  2013
#
# [1 rows x 21 columns]

# %%
df[df['profit'] ==df["profit"].max()]["customer_name"]
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df[df['country']=='Sweden']
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183    2/3/2011    2/5/2011    Second Class
# 1342   IT-2011-5233011   3/31/2011    4/6/2011  Standard Class
# 1554   IT-2011-2419493   4/12/2011   4/13/2011     First Class
# ...                ...         ...         ...             ...
# 50948  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50949  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50972  IT-2014-4046179  12/27/2014  12/30/2014    Second Class
# 51086  IT-2014-2362249  12/29/2014    1/1/2015     First Class
# 51121  IT-2014-2362249  12/29/2014    1/1/2015     First Class
#
#          customer_name      segment            state country market region  \
# 3         Eugene Moren  Home Office        Stockholm  Sweden     EU  North
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df[df["shipping_cost"]>10]
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 0        AG-2011-2040    1/1/2011  1/6/2011  Standard Class   Toby Braunhardt
# 6        CA-2011-1510    1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7       IN-2011-79397    1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8       ID-2011-80230    1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9        IZ-2011-4680    1/3/2011  1/7/2011  Standard Class  Lindsay Williams
# ...               ...         ...       ...             ...               ...
# 51250   IN-2014-78228  12/31/2014  1/6/2015  Standard Class       Maya Herman
# 51251  MX-2014-122511  12/31/2014  1/5/2015  Standard Class         Rick Reed
# 51252    OD-2014-9490  12/31/2014  1/5/2015  Standard Class  Mitch Willingham
# 51253    AO-2014-7730  12/31/2014  1/4/2015  Standard Class      Ken Lonsdale
# 51254  MX-2014-158827  12/31/2014  1/2/2015     First Class     Tracy Collins
#
# ...

# %%
df[(df["shipping_cost"]>100) & (df["profit"]<10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df["order_date"]=pd.to_datetime(df["order_date"])

# %%
df.dtypes
# Out:
# order_id                  object
# order_date        datetime64[ns]
# ship_date                 object
# ship_mode                 object
# customer_name             object
# segment                   object
# state                     object
# country                   object
# market                    object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                     object
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# order_priority            object
# year                       int64
# dtype: object

# %%
df['order_date_year']=df["order_date"].dt.year

# %%
df['order_date_year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 51285    2014
# 51286    2014
# 51287    2014
# 51288    2014
# 51289    2014
# Name: order_date_year, Length: 51290, dtype: int64

# %%
df['order_date_month']=df["order_date"].dt.month

# %%
df['order_date_month'].value_counts() #it first groupby then it counts the number of occurence
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df['order_date_week']=df["order_date"].dt.weekofyear
# Out:
# C:\Users\ADNAN\AppData\Local\Temp/ipykernel_8020/1575448512.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['order_date_week']=df["order_date"].dt.weekofyear

# %%
df['order_date_week']
# Out:
# 0        52
# 1        52
# 2        52
# 3        52
# 4        52
#          ..
# 51285     1
# 51286     1
# 51287     1
# 51288     1
# 51289     1
# Name: order_date_week, Length: 51290, dtype: int64

# %%
df.drop("order_date_week",axis=1, inplace =True)

# %%
df.loc[2:4]
# Out:
#           order_id order_date ship_date       ship_mode  customer_name  \
# 2     HU-2011-1220 2011-01-01  1/5/2011    Second Class  Annie Thurman
# 3  IT-2011-3647632 2011-01-01  1/5/2011    Second Class   Eugene Moren
# 4    IN-2011-47883 2011-01-01  1/8/2011  Standard Class    Joseph Holt
#
#        segment            state    country market   region  ...  \
# 2     Consumer         Budapest    Hungary   EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden     EU    North  ...
# 4     Consumer  New South Wales  Australia   APAC  Oceania  ...
#
#                   product_name sales quantity discount  profit  shipping_cost  \
# 2      Tenex Box, Single Width    66        4      0.0  29.640           8.17
# 3  Enermax Note Cards, Premium    45        3      0.5 -26.055           4.82
# 4   Eldon Light Bulb, Duo Pack   114        5      0.1  37.770           4.70
#
#    order_priority  year  order_date_year order_date_month
# ...

# %%
df.loc[[2,5]]
# Out:
#         order_id order_date ship_date       ship_mode  customer_name  \
# 2   HU-2011-1220 2011-01-01  1/5/2011    Second Class  Annie Thurman
# 5  IN-2011-47883 2011-01-01  1/8/2011  Standard Class    Joseph Holt
#
#     segment            state    country market   region  ...  \
# 2  Consumer         Budapest    Hungary   EMEA     EMEA  ...
# 5  Consumer  New South Wales  Australia   APAC  Oceania  ...
#
#                               product_name sales quantity discount  profit  \
# 2                  Tenex Box, Single Width    66        4      0.0  29.640
# 5  Eaton Computer Printout Paper, 8.5 x 11    55        2      0.1  15.342
#
#    shipping_cost  order_priority  year  order_date_year order_date_month
# 2           8.17            High  2011             2011                1
# 5           1.80          Medium  2011             2011                1
#
# [2 rows x 23 columns]

# %%
df.loc[0:4,['order_id','order_date','ship_date']]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040 2011-01-01  1/6/2011
# 1    IN-2011-47883 2011-01-01  1/8/2011
# 2     HU-2011-1220 2011-01-01  1/5/2011
# 3  IT-2011-3647632 2011-01-01  1/5/2011
# 4    IN-2011-47883 2011-01-01  1/8/2011

# %%
df.loc[0:4,'order_id':'ship_date']
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040 2011-01-01  1/6/2011
# 1    IN-2011-47883 2011-01-01  1/8/2011
# 2     HU-2011-1220 2011-01-01  1/5/2011
# 3  IT-2011-3647632 2011-01-01  1/5/2011
# 4    IN-2011-47883 2011-01-01  1/8/2011

# %%
df.iloc[0:4,0:3]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040 2011-01-01  1/6/2011
# 1    IN-2011-47883 2011-01-01  1/8/2011
# 2     HU-2011-1220 2011-01-01  1/5/2011
# 3  IT-2011-3647632 2011-01-01  1/5/2011

# %%
df.iloc[2:6,3:6]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
df.dtypes[(df.dtypes=='float64')|(df.dtypes=='int64')]
# Out:
# quantity              int64
# discount            float64
# profit              float64
# shipping_cost       float64
# year                  int64
# order_date_year       int64
# order_date_month      int64
# dtype: object

# %%
df.dtypes[(df.dtypes=='float64')|(df.dtypes=='int64')].index
# Out:
# Index(['quantity', 'discount', 'profit', 'shipping_cost', 'year',
#        'order_date_year', 'order_date_month'],
#       dtype='object')

# %%
df2=df[df.dtypes[(df.dtypes=='float64')|(df.dtypes=='int64')].index]

# %%
df3=df2[df2>100]

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 1           NaN       NaN     NaN            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month
# 0                   NaN
# 1                   NaN
# 2                   NaN
# ...

# %%
df3.dropna(axis=1)
# Out:
#        year  order_date_year
# 0      2011             2011
# 1      2011             2011
# 2      2011             2011
# 3      2011             2011
# 4      2011             2011
# ...     ...              ...
# 51285  2014             2014
# 51286  2014             2014
# 51287  2014             2014
# 51288  2014             2014
# 51289  2014             2014
#
# [51290 rows x 2 columns]

# %%
df3.dropna(thresh=3)
# Out:
#        quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.140            NaN  2011             2011
# 7           NaN       NaN  110.412         125.32  2011             2011
# 8           NaN       NaN      NaN         107.10  2011             2011
# 9           NaN       NaN  253.320            NaN  2011             2011
# 12          NaN       NaN  290.430            NaN  2011             2011
# ...         ...       ...      ...            ...   ...              ...
# 51234       NaN       NaN  216.720            NaN  2014             2014
# 51236       NaN       NaN  180.240            NaN  2014             2014
# 51245       NaN       NaN  105.000            NaN  2014             2014
# 51252       NaN       NaN  166.440            NaN  2014             2014
# 51269       NaN       NaN  153.090            NaN  2014             2014
#
#        order_date_month
# 0                   NaN
# 7                   NaN
# ...

# %%
df3.fillna(value=4)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           4.0       4.0  106.14            4.0  2011             2011
# 1           4.0       4.0    4.00            4.0  2011             2011
# 2           4.0       4.0    4.00            4.0  2011             2011
# 3           4.0       4.0    4.00            4.0  2011             2011
# 4           4.0       4.0    4.00            4.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       4.0       4.0    4.00            4.0  2014             2014
# 51286       4.0       4.0    4.00            4.0  2014             2014
# 51287       4.0       4.0    4.00            4.0  2014             2014
# 51288       4.0       4.0    4.00            4.0  2014             2014
# 51289       4.0       4.0    4.00            4.0  2014             2014
#
#        order_date_month
# 0                   4.0
# 1                   4.0
# 2                   4.0
# ...

# %%
df.groupby("year")["profit"].mean()
# Out:
# year
# 2011    27.666238
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.groupby('year')['shipping_cost'].mean()
# Out:
# year
# 2011    27.147264
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
df.groupby('year')['discount'].mean()
# Out:
# year
# 2011    0.148188
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
df.sales.astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8020/40868035.py in <module>
# ----> 1 df.sales.astype("int")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df.sales=df.sales.str.replace(',','')

# %%
df.sales
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: object

# %%
df.sales.astype('int')
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: int32
